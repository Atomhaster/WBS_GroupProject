# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os, random

from modules.painting import painting
from modules.database import database as db

from keras.models import Sequential, Model
from keras.layers.core import (Dropout, Flatten, Dense, Activation)
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import (RandomFlip, RandomRotation, Input, BatchNormalization, 
                          RandomTranslation, RandomZoom)
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.applications.vgg19 import VGG19, preprocess_input

from tensorflow import unique_with_counts

# %% [markdown]
# #### Control Variables

# %%
# setting path variables for Working Directory and folder to save and load
#   models from.
wd = os.getcwd()
WD_PATH =  os.path.abspath(wd)
PATH_TRAINING = os.path.join(WD_PATH, "model_training")

# # initializing the database object
gallery = db()

# Size of the pictures when reduced in size
PIXEL_SIZE = 256

# the proportions to split the available paintings in training
# and testing.
keep_unused = 10
prop_train = 0.8
prop_test = 0.2

# selection  of artists to use. (our ids)
# 3,4,10 = Pierre-Auguste Renoir, Francisco Goya, Paul Gauguin
artists = [3,4,10]
count_artists = len(artists)

# defining labels in a list
class_names = []
for k in artists:
    class_names.append(gallery.get_artist(k)[0][1])

# %%
# checking the available paintings per artist.
num_paintings = np.zeros(count_artists,np.int16)
for j in range(count_artists):
    num_paintings[j] = len(gallery.get_paintingids_from_artist(artists[j]))
print(num_paintings)
# Total number of paintings available
TOTAL_PAINTINGS = sum(num_paintings)
# Out:
# [336 291 311]

# %%
# Weights for the model:
class_temp = TOTAL_PAINTINGS / num_paintings
class_weights = {}
for i in range(count_artists):
    class_weights[i] = class_temp[i]
class_weights
# Out:
# {0: 2.7916666666666665, 1: 3.223367697594502, 2: 3.0160771704180065}

# %%
# coding the sizes needed as collection arrays for the input data
SIZE_P_TRAINING = 0
training_size_paintings = num_paintings.copy()
SIZE_P_TESTING = 0
testing_size_paintings = num_paintings.copy()
for i in range(count_artists):
    train_count = int((num_paintings[i] - keep_unused)  * prop_train)
    test_count = int((num_paintings[i] - keep_unused)  * prop_test)
    # print(sum((train_count,test_count,10)),training_size_paintings[i])
    SIZE_P_TRAINING += train_count
    SIZE_P_TESTING += test_count
    training_size_paintings[i] = train_count
    testing_size_paintings[i] = test_count
print("total train paintings:", SIZE_P_TRAINING)
print("total test paintings:", SIZE_P_TESTING)
# Out:
# total train paintings: 724
# total test paintings: 181

# %% [markdown]
# #### Loading data from DB

# %%
## creating arrays to hold the pictures taken from the DB
training_images = np.zeros((SIZE_P_TRAINING,PIXEL_SIZE,PIXEL_SIZE,3))
index_training = 0
skip_count_training = 0
testing_images = np.zeros((SIZE_P_TESTING,PIXEL_SIZE,PIXEL_SIZE,3))
index_testing = 0
skip_count_testing = 0
# creating the arrays to hold labels. In this case they are the artist ids.
training_labels = np.array([0]*SIZE_P_TRAINING,dtype=int)
testing_labels = np.array([0]*SIZE_P_TESTING,dtype=int)
unused_paintings = np.array(
    [0]*(TOTAL_PAINTINGS-SIZE_P_TESTING-SIZE_P_TRAINING)
    ,dtype=int)
# checking if the numbers add up.
print(training_images.shape)
print(testing_images.shape)
print(training_labels.shape)
print(testing_labels.shape)
print(unused_paintings.shape)
# Out:
# (724, 256, 256, 3)
# (181, 256, 256, 3)
# (724,)
# (181,)
# (33,)

# %% [markdown]
# Loop over the artists and adding randomized pictures of them to the <br>
# training and testing sets. There are also ids collected, which are unused, <br>
# so that they can be used as "new, unseen" input for the model.

# %%
# filling the arrays with picture arrays. They will be resized according
# to the pixel_size value
unused_index = 0
for i in range(count_artists):
    # loading all ids from the artist
    ids = gallery.get_paintingids_from_artist(artists[i])
    # shuffle the ids to get random order for selection
    random.seed(1983)
    random.shuffle(ids)
    
    # getting the numbers for the current artist:
    _str = training_size_paintings[i]
    _ste = testing_size_paintings[i]
    # slicing the ids for training and testing of artist with id i+1
    ids_training = ids[ : _str]
    ids_testing = ids[_str : _str + _ste]
    ids_unused = ids[ _str + _ste : ]
    
    # collecting the ids of the unused paintings
    for l, f in zip(range(unused_index,unused_index+len(ids_unused))
                    , ids_unused):
        unused_paintings[l] = f[0]
    unused_index += len(ids_unused)
    
    # retrieving the paintings from the db, resizing them and collecting
    # them in the training_images array while also filling the labels
    for k in ids_training:
        temp_p = painting("local DB", id=k[0])
        temp_p_res = cv.resize(temp_p.ndarray, dsize=(PIXEL_SIZE,PIXEL_SIZE)
                               ,interpolation=cv.INTER_CUBIC)
        if temp_p_res.shape == (PIXEL_SIZE,PIXEL_SIZE,3):
            training_images[index_training] = temp_p_res
            training_labels[index_training] = i
            index_training += 1
        else:
            skip_count_training += 1
            
    # retrieving the paintings from the db, resizing them and collecting
    # them in the testing_images array while also filling the labels
    for j in ids_testing:
        temp_p = painting("local DB", id=j[0])
        temp_p_res = cv.resize(temp_p.ndarray, dsize=(PIXEL_SIZE,PIXEL_SIZE)
                               ,interpolation=cv.INTER_CUBIC)
        if temp_p_res.shape == (PIXEL_SIZE,PIXEL_SIZE,3):
            testing_images[index_testing] = temp_p_res
            testing_labels[index_testing] = i
            # testing_labels[index_testing] = [temp_p.artist_id-1,]
            index_testing += 1
        else:
            skip_count_testing += 1

# ## dropping the last few array positions of testing images, which where 
# ## not filled.
testing_images = testing_images[:index_testing,:,:,:]
testing_labels = testing_labels[:index_testing]
# ## dropping the last few array positions of training images, which where 
# ## not filled.
training_images = training_images[:index_training,:,:,:]
training_labels = training_labels[:index_training]

# # the pixels on an image are rescaled from 0-255 to 0-1 
training_images, testing_images = training_images/255, testing_images/255

# %% [markdown]
# #### Checking data shapes

# %%
print(training_images.shape)
print(testing_images.shape)
print(training_labels.shape)
print(testing_labels.shape)
print(type(training_labels[185:200]))
print(unused_paintings.shape)
# Out:
# (653, 256, 256, 3)
# (160, 256, 256, 3)
# (653,)
# (160,)
# <class 'numpy.ndarray'>
# (33,)

# %% [markdown]
# ***
# Creating the weight vector for the artists.

# %% [markdown]
# #### Checking data counts

# %%
y_tl, idx_tl, count_tl = unique_with_counts(training_labels)
y_testl, idx_testl, count_testl = unique_with_counts(testing_labels)
y_unused, idx_unused, count_unused = unique_with_counts(unused_paintings)

# %%
print(y_tl, count_tl)
print(y_testl, count_testl)
print(unique_with_counts(count_unused)[2])
# Out:
# tf.Tensor([0 1 2], shape=(3,), dtype=int32) tf.Tensor([260 153 240], shape=(3,), dtype=int32)
# tf.Tensor([0 1 2], shape=(3,), dtype=int32) tf.Tensor([65 35 60], shape=(3,), dtype=int32)
# tf.Tensor([33], shape=(1,), dtype=int32)

# %% [markdown]
# ***
# ## Modelling part
# ####  creating the model

# %%
base_model = VGG19(include_top = False,
                   classes = count_artists, 
                   input_shape = (PIXEL_SIZE, PIXEL_SIZE, 3))

base_model.trainable = False
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Layer for the model. 
## data augmentation counteracting the small number of paintings
data_augmentation = Sequential([
    RandomFlip('horizontal'),
    RandomFlip('vertical'),
    RandomRotation(0.2),
    RandomZoom(0.1),
    RandomTranslation(0.1, 0.1),
])
prediction = Sequential([
    Flatten(),
    Dense(512),
    BatchNormalization(),
    Dropout(0.1),
    Dense(512),
    Dense(count_artists, activation = 'softmax'),
])

# %%
# Creating the model from basemodel and the other layers.
inputs = Input(shape=(PIXEL_SIZE, PIXEL_SIZE, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
outputs = prediction(x)
model = Model(inputs, outputs)

# %%
# compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  tf.__operators__.getitem (S  (None, 256, 256, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 256, 256, 3)      0
#
#  vgg19 (Functional)          (None, 8, 8, 512)         20024384
#
#  sequential_1 (Sequential)   (None, 3)                 17043971
#
# =================================================================
# Total params: 37,068,355
# Trainable params: 17,042,947
# Non-trainable params: 20,025,408
# _________________________________________________________________

# %%
## training the model
epochs = 100
batch_size = 8

early_stopping = EarlyStopping(patience = 20, 
                               verbose = 2, 
                               restore_best_weights = True)
    
history = model.fit(training_images,
                    training_labels,
                    validation_data = (testing_images, testing_labels),
                    class_weight = class_weights,
                    epochs = epochs,
                    batch_size = batch_size,
                    callbacks = early_stopping)
# Out:
# Epoch 1/100
# 82/82 [==============================] - 109s 1s/step - loss: 7.7800 - accuracy: 0.4196 - val_loss: 47.1931 - val_accuracy: 0.2188
# Epoch 2/100
# 82/82 [==============================] - 112s 1s/step - loss: 4.6850 - accuracy: 0.4962 - val_loss: 5.1068 - val_accuracy: 0.2188
# Epoch 3/100
# 82/82 [==============================] - 110s 1s/step - loss: 4.0066 - accuracy: 0.4870 - val_loss: 41.7976 - val_accuracy: 0.2188
# Epoch 4/100
# 82/82 [==============================] - 110s 1s/step - loss: 3.3330 - accuracy: 0.4732 - val_loss: 84.0025 - val_accuracy: 0.2188
# Epoch 5/100
# 82/82 [==============================] - 110s 1s/step - loss: 3.0351 - accuracy: 0.5421 - val_loss: 23.8098 - val_accuracy: 0.2188
# Epoch 6/100
# 82/82 [==============================] - 109s 1s/step - loss: 3.0518 - accuracy: 0.5391 - val_loss: 52.3755 - val_accuracy: 0.2188
# Epoch 7/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7099 - accuracy: 0.5727 - val_loss: 10.5682 - val_accuracy: 0.2188
# Epoch 8/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.8026 - accuracy: 0.5697 - val_loss: 14.3057 - val_accuracy: 0.2188
# Epoch 9/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7478 - accuracy: 0.5758 - val_loss: 10.3601 - val_accuracy: 0.2188
# Epoch 10/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7634 - accuracy: 0.5651 - val_loss: 20.2394 - val_accuracy: 0.2188
# Epoch 11/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7657 - accuracy: 0.5651 - val_loss: 8.9437 - val_accuracy: 0.2188
# Epoch 12/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.8011 - accuracy: 0.5452 - val_loss: 12.6860 - val_accuracy: 0.2188
# Epoch 13/100
# 82/82 [==============================] - 110s 1s/step - loss: 2.6871 - accuracy: 0.6110 - val_loss: 7.3651 - val_accuracy: 0.4938
# Epoch 14/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7279 - accuracy: 0.5957 - val_loss: 20.1062 - val_accuracy: 0.2188
# Epoch 15/100
# 82/82 [==============================] - 110s 1s/step - loss: 2.7299 - accuracy: 0.5651 - val_loss: 10.5622 - val_accuracy: 0.4563
# Epoch 16/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.8183 - accuracy: 0.5697 - val_loss: 22.3593 - val_accuracy: 0.2188
# Epoch 17/100
# 82/82 [==============================] - 110s 1s/step - loss: 2.7359 - accuracy: 0.5896 - val_loss: 7.2341 - val_accuracy: 0.4125
# Epoch 18/100
# 82/82 [==============================] - 110s 1s/step - loss: 2.6047 - accuracy: 0.5865 - val_loss: 3.5454 - val_accuracy: 0.4313
# Epoch 19/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.6191 - accuracy: 0.6141 - val_loss: 12.6940 - val_accuracy: 0.3750
# Epoch 20/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.6728 - accuracy: 0.5789 - val_loss: 17.9854 - val_accuracy: 0.2188
# Epoch 21/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7478 - accuracy: 0.5651 - val_loss: 24.5185 - val_accuracy: 0.2188
# Epoch 22/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.7535 - accuracy: 0.5651 - val_loss: 17.2001 - val_accuracy: 0.2188
# Epoch 23/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.6324 - accuracy: 0.6248 - val_loss: 24.0578 - val_accuracy: 0.2188
# Epoch 24/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.5988 - accuracy: 0.5850 - val_loss: 7.2135 - val_accuracy: 0.2188
# Epoch 25/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7250 - accuracy: 0.5712 - val_loss: 34.3261 - val_accuracy: 0.2188
# Epoch 26/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7208 - accuracy: 0.5881 - val_loss: 9.4309 - val_accuracy: 0.2188
# Epoch 27/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.5919 - accuracy: 0.6018 - val_loss: 21.0978 - val_accuracy: 0.2188
# Epoch 28/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7057 - accuracy: 0.6018 - val_loss: 2.7608 - val_accuracy: 0.4250
# Epoch 29/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7809 - accuracy: 0.5819 - val_loss: 5.2758 - val_accuracy: 0.3812
# Epoch 30/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6442 - accuracy: 0.5789 - val_loss: 8.9492 - val_accuracy: 0.4313
# Epoch 31/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5950 - accuracy: 0.5835 - val_loss: 35.9974 - val_accuracy: 0.2188
# Epoch 32/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7449 - accuracy: 0.5819 - val_loss: 2.4481 - val_accuracy: 0.4313
# Epoch 33/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7286 - accuracy: 0.5712 - val_loss: 3.7297 - val_accuracy: 0.4375
# Epoch 34/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5230 - accuracy: 0.6263 - val_loss: 3.3849 - val_accuracy: 0.4563
# Epoch 35/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.5986 - accuracy: 0.6049 - val_loss: 36.8400 - val_accuracy: 0.2188
# Epoch 36/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7286 - accuracy: 0.5605 - val_loss: 38.3523 - val_accuracy: 0.2188
# Epoch 37/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5637 - accuracy: 0.6172 - val_loss: 38.1383 - val_accuracy: 0.2188
# Epoch 38/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7127 - accuracy: 0.5804 - val_loss: 25.1938 - val_accuracy: 0.2188
# Epoch 39/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5524 - accuracy: 0.6126 - val_loss: 9.8883 - val_accuracy: 0.4187
# Epoch 40/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6869 - accuracy: 0.6064 - val_loss: 4.4458 - val_accuracy: 0.4250
# Epoch 41/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6079 - accuracy: 0.6049 - val_loss: 7.1786 - val_accuracy: 0.4187
# Epoch 42/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.6593 - accuracy: 0.6018 - val_loss: 7.0597 - val_accuracy: 0.3750
# Epoch 43/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6382 - accuracy: 0.5743 - val_loss: 6.3844 - val_accuracy: 0.2188
# Epoch 44/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.5721 - accuracy: 0.6003 - val_loss: 9.3470 - val_accuracy: 0.2188
# Epoch 45/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5700 - accuracy: 0.6003 - val_loss: 2.5368 - val_accuracy: 0.4625
# Epoch 46/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.6080 - accuracy: 0.6126 - val_loss: 11.5657 - val_accuracy: 0.2188
# Epoch 47/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6610 - accuracy: 0.6095 - val_loss: 6.9615 - val_accuracy: 0.5375
# Epoch 48/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6230 - accuracy: 0.6064 - val_loss: 45.1975 - val_accuracy: 0.2188
# Epoch 49/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6447 - accuracy: 0.5881 - val_loss: 8.5484 - val_accuracy: 0.3812
# Epoch 50/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5501 - accuracy: 0.6202 - val_loss: 4.9160 - val_accuracy: 0.4187
# Epoch 51/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5491 - accuracy: 0.6187 - val_loss: 18.0907 - val_accuracy: 0.2188
# Epoch 52/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5463 - accuracy: 0.5896 - val_loss: 2.3679 - val_accuracy: 0.3187
# Epoch 53/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.5935 - accuracy: 0.5896 - val_loss: 12.3020 - val_accuracy: 0.4187
# Epoch 54/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5854 - accuracy: 0.6003 - val_loss: 9.5257 - val_accuracy: 0.2188
# Epoch 55/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5838 - accuracy: 0.6187 - val_loss: 16.3425 - val_accuracy: 0.4062
# Epoch 56/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5131 - accuracy: 0.6248 - val_loss: 4.3669 - val_accuracy: 0.2188
# Epoch 57/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5151 - accuracy: 0.6279 - val_loss: 5.8739 - val_accuracy: 0.4125
# Epoch 58/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.7036 - accuracy: 0.6003 - val_loss: 20.9692 - val_accuracy: 0.2188
# Epoch 59/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5876 - accuracy: 0.6172 - val_loss: 6.9596 - val_accuracy: 0.4437
# Epoch 60/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.4520 - accuracy: 0.6141 - val_loss: 11.0495 - val_accuracy: 0.2188
# Epoch 61/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.5109 - accuracy: 0.6217 - val_loss: 5.7398 - val_accuracy: 0.4750
# Epoch 62/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.6844 - accuracy: 0.5758 - val_loss: 11.1279 - val_accuracy: 0.2188
# Epoch 63/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.5538 - accuracy: 0.5972 - val_loss: 15.1479 - val_accuracy: 0.2375
# Epoch 64/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5699 - accuracy: 0.6095 - val_loss: 6.4888 - val_accuracy: 0.3938
# Epoch 65/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5418 - accuracy: 0.6309 - val_loss: 10.5854 - val_accuracy: 0.3750
# Epoch 66/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.5789 - accuracy: 0.6126 - val_loss: 10.9243 - val_accuracy: 0.4125
# Epoch 67/100
# 82/82 [==============================] - 107s 1s/step - loss: 2.6249 - accuracy: 0.6064 - val_loss: 5.7196 - val_accuracy: 0.4625
# Epoch 68/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.5439 - accuracy: 0.6034 - val_loss: 3.0139 - val_accuracy: 0.2250
# Epoch 69/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.5150 - accuracy: 0.6248 - val_loss: 5.4035 - val_accuracy: 0.4250
# Epoch 70/100
# 82/82 [==============================] - 109s 1s/step - loss: 2.6107 - accuracy: 0.6049 - val_loss: 5.8025 - val_accuracy: 0.3875
# Epoch 71/100
# 82/82 [==============================] - 108s 1s/step - loss: 2.4678 - accuracy: 0.6095 - val_loss: 9.1924 - val_accuracy: 0.4062
# Epoch 72/100
# 82/82 [==============================] - ETA: 0s - loss: 2.6473 - accuracy: 0.5850Restoring model weights from the end of the best epoch: 52.
# 82/82 [==============================] - 109s 1s/step - loss: 2.6473 - accuracy: 0.5850 - val_loss: 8.9493 - val_accuracy: 0.2188
# Epoch 72: early stopping

# %%
model.save(os.path.join(PATH_TRAINING,"IC_VGG19base_3Artists_Renoir_Goy_Gauguin.model"))
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: c:\Users\bvondewitz\Documents\CodeBase\GruppenProjekt\model_training\IC_VGG19base_3Artists_Renoir_Goy_Gauguin.model\assets
# INFO:tensorflow:Assets written to: c:\Users\bvondewitz\Documents\CodeBase\GruppenProjekt\model_training\IC_VGG19base_3Artists_Renoir_Goy_Gauguin.model\assets

# %%
model = models.load_model(os.path.join(PATH_TRAINING,"IC_VGG19base_3Artists_Renoir_Goy_Gauguin.model"))

# %% [markdown]
# #### check one prediction

# %%
test_painting = painting("local DB",random.choice(unused_paintings))
print(test_painting.id)
test_ndarray = cv.resize(test_painting.ndarray, dsize=(PIXEL_SIZE,PIXEL_SIZE)
                               ,interpolation=cv.INTER_CUBIC)
test_ndarray = test_ndarray/255
temp_array = np.zeros((1,PIXEL_SIZE,PIXEL_SIZE,3))
print(temp_array.shape)
temp_array[0] = test_ndarray
prediction = model.predict(temp_array)
np.set_printoptions(suppress=True)
print(np.round(prediction, 4))
print(np.argmax(prediction))
index = np.argmax(prediction)
print(f"Prediction is {class_names[index]}")

art_id = gallery.get_painting(test_painting.id)[1]
print("actual Artist is ", gallery.get_artist(art_id)[0][1])

imgplot = plt.imshow(test_painting.ndarray)
plt.show()
# Out:
# 1622
# (1, 256, 256, 3)
# 1/1 [==============================] - 0s 142ms/step
# [[0.3651 0.6256 0.0094]]
# 1
# Prediction is Francisco Goya
# actual Artist is  Pierre-Auguste Renoir
